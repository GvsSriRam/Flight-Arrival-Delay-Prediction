# %% [markdown]
# This file contains the code to merge the flights departure data from various airports into one single CSV file.

# %%
# Generic inputs for most ML tasks
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn import tree
# import graphviz
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestClassifier

pd.options.display.float_format = '{:,.2f}'.format

# setup interactive notebook mode
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from IPython.display import display, HTML

# %%
import os
from pathlib import Path

# Define the path to the data directory
data_path = Path.joinpath(Path.cwd(), "data")

# %%
departures_data_path = data_path.joinpath("departures")
departures_data_path
# Out:
# PosixPath('/Users/gvssriram/Desktop/MS/ML/Project/project_24/data/departures')

# %%
df = pd.DataFrame()

for folder in os.listdir(departures_data_path):
    if folder == '.DS_Store':
        continue
    # print(folder)
    for file in os.listdir(departures_data_path.joinpath(folder)):
        if file == '.DS_Store':
            continue
        path = departures_data_path.joinpath(folder).joinpath(file)
        df_ = pd.read_csv(path, skiprows=[0, 1, 2, 3, 4, 5, 6], dtype=str)
        df_ = df_[df_["Destination Airport"] == "SYR"]
        df_["Origin Airport"] = folder
        df = pd.concat([df, df_])

df.head()
# Out:
#     Carrier Code Date (MM/DD/YYYY) Flight Number Tail Number  \
# 53            G4        01/02/2020          1737       241NV
# 102           G4        01/03/2019          1720       226NV
# 121           G4        01/03/2021          1744       245NV
# 137           G4        01/03/2022          0962       222NV
# 152           G4        01/03/2023          0523       234NV
#
#     Destination Airport Scheduled departure time Actual departure time  \
# 53                  SYR                    06:30                 06:29
# 102                 SYR                    06:50                 06:49
# 121                 SYR                    16:25                 17:40
# 137                 SYR                    06:15                 06:15
# 152                 SYR                    06:30                 10:34
#
#     Scheduled elapsed time (Minutes) Actual elapsed time (Minutes)  \
# 53                               176                           167
# 102                              182                           167
# 121                              178                           168
# 137                              176                           175
# 152                              182                           170
#
#     Departure delay (Minutes) Wheels-off time Taxi-Out time (Minutes)  \
# 53                         -1           06:42                      13
# 102                        -1           07:01                      12
# 121                        75           17:53                      13
# 137                         0           06:30                      15
# 152                       244           10:51                      17
#
#     Delay Carrier (Minutes) Delay Weather (Minutes)  \
# 53                        0                       0
# 102                       0                       0
# 121                       0                       0
# 137                       0                       0
# 152                     232                       0
#
#     Delay National Aviation System (Minutes) Delay Security (Minutes)  \
# 53                                         0                        0
# 102                                        0                        0
# 121                                        0                        0
# 137                                        0                        0
# 152                                        0                        0
#
#     Delay Late Aircraft Arrival (Minutes) Origin Airport
# 53                                      0            FLL
# 102                                     0            FLL
# 121                                    65            FLL
# 137                                     0            FLL
# 152                                     0            FLL

# %%
df.reset_index(inplace=True)
df.to_csv("data/aggregated/departures.csv")
